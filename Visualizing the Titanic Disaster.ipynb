# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic =pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv')
titanic
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# ...

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId', inplace=True)
titanic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7200\2114284967.py in <module>
# ----> 1 titanic.set_index('PassengerId', inplace=True)
#       2 titanic
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
gender_counts = titanic['Sex'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Male/Female Proportion')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
plt.scatter(titanic['Age'], titanic['Fare'], c=titanic['Sex'].map({'female': 'purple', 'male': 'green'}), alpha=0.5)
plt.title('Fare Paid vs. Age by Gender')
plt.xlabel('Age')
plt.ylabel('Fare Paid')
plt.legend(handles=[plt.Line2D([], [], marker='o', color='purple', label='Female'),
                    plt.Line2D([], [], marker='o', color='green', label='Male')])

plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic['Survived'].value_counts()[1]
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
plt.hist(titanic['Fare'], bins=20)
plt.title('Distribution of Fare Paid')
plt.xlabel('Fare Paid')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
#Question: How does the age distribution vary by passenger class in the Titanic dataset?
plt.boxplot([titanic[titanic['Pclass'] == 1]['Age'].dropna(),
             titanic[titanic['Pclass'] == 2]['Age'].dropna(),
             titanic[titanic['Pclass'] == 3]['Age'].dropna()])

plt.title('Age Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.xticks([1, 2, 3], ['First Class', 'Second Class', 'Third Class'])
plt.show()
